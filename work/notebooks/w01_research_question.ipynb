# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ahmed-Ehab33/FlyRank-ML-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ##  1. i chose the Decline Recovery lane because I am interested in using machine learning to identify web pages that are likely to lose performance before the decline becomes significant. This problem has a clear business value because content teams cannot manually review thousands of pages. A prediction system can help prioritize which pages should be refreshed first, allowing teams to focus their time on the pages with the highest potential impact.

# %% [markdown]
# ## 2. My research aims to improve the decision of which web pages should be refreshed first before their search performance declines. The content and SEO teams will use these recommendations to prioritize which pages should be reviewed and updated instead of checking every page manually. A wrong recommendation could waste time and resources by refreshing pages that do not need updates. It could also miss pages that are actually declining, resulting in lost search traffic and missed opportunities to improve content performance.

# %% [markdown]
# ### 3. Key observations from the starter dataset
#
# - The dataset contains **16,262** pages labeled as **"down"**, making it the largest trend category. This suggests that content decline is a common problem worth investigating.
#
# - The correlation between **search_volume** and **impressions_90d** is close to **0**, indicating that search volume alone is not a reliable indicator of page performance.
#
# - These observations suggest that identifying declining pages is not a simple rule-based task, making the Decline Recovery lane a good candidate for data analysis and machine learning.

# %%
import pandas as pd
df = pd.read_csv(r"C:\Python\FlyRank-ML-internship\data\raw\content_refresh_anonymized.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   content_id              30000 non-null  str
#  1   client_id               30000 non-null  str
#  2   search_volume           27532 non-null  float64
#  3   competition             27532 non-null  float64
#  4   competition_level       27390 non-null  str
#  5   cpc                     27532 non-null  float64
#  6   content_type            30000 non-null  str
#  7   main_intent             27626 non-null  str
#  8   word_count              22301 non-null  float64
#  9   char_count              22301 non-null  float64
#  10  provider_used           8562 non-null   str
#  11  model_used              24267 non-null  str
#  12  impressions_90d         30000 non-null  int64
#  13  clicks_90d              30000 non-null  int64
# ...

# %%
print("Trend distribution:")
print(df["trend_direction"].value_counts())

print("\nCorrelation between search volume and impressions:")
print(df["search_volume"].corr(df["impressions_90d"]))
# Out:
# Trend distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Correlation between search volume and impressions:
# 0.001203031069620889

# %% [markdown]
# ## This project can identify patterns that are associated with pages that are declining and help prioritize which pages should be reviewed first. The results are intended to support SEO and content teams in making better decisions based on data.
#
# ## However, this project cannot prove why a page is declining or predict Google's algorithm. It also cannot guarantee that updating a page will improve its search performance. The findings should be treated as decision support based on the available data, not as causal proof.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅️] Every section above is filled — markdown thinking AND the code that backs it
# - [✅️] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅️] No client names, URLs, or private queries anywhere
# - [✅️] My claims use careful words: observed, measured, directional, decision-support
# - [✅️] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
